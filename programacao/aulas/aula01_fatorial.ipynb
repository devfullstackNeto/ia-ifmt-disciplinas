# %% [markdown]
# <a href="https://colab.research.google.com/github/devfullstackNeto/ia-ifmt-disciplinas/blob/main/programacao/aulas/aula01_fatorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int(input("Digite um número: "))
fatorial = 1
n = numero

while numero >= 1:
    fatorial = fatorial * numero

    if numero > 1:
        print(numero, end=" x ")
    else:
        print(numero, end=" = ")

    numero = numero - 1

print(fatorial)
# Out:
# Digite um número: 6
# 6 x 5 x 4 x 3 x 2 x 1 = 720
